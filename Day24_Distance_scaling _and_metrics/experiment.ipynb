# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("dataset.csv")

X = df[['age', 'salary']].values
y = df['label'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model1=KNeighborsClassifier(n_neighbors=2,metric="euclidean")
model1.fit(X_train,y_train)
pred1=model1.predict(X_test)
print("Without Scaling Accuracy:", accuracy_score(y_test, pred1))
# Out:
# Without Scaling Accuracy: 0.8

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
model2 = KNeighborsClassifier(n_neighbors=2, metric='euclidean')
model2.fit(X_train_scaled, y_train)

pred2 = model2.predict(X_test_scaled)
print("With Scaling Accuracy:", accuracy_score(y_test, pred2))
# Out:
# With Scaling Accuracy: 1.0

# %%
model3 = KNeighborsClassifier(n_neighbors=2, metric='manhattan')
model3.fit(X_train_scaled, y_train)

pred3 = model3.predict(X_test_scaled)
print("Manhattan Distance Accuracy:", accuracy_score(y_test, pred3))
# Out:
# Manhattan Distance Accuracy: 1.0
