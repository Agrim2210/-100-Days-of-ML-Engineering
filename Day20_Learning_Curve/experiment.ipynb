# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import learning_curve
from sklearn.linear_model import LinearRegression

df=pd.read_csv("dataset.csv")

# %%
X = df[["area","rooms"]]
y = df["price"]

model = LinearRegression()
train_sizes, train_scores, val_scores = learning_curve(
    model, X, y, cv=3, scoring="neg_mean_squared_error",
    train_sizes=np.linspace(0.3, 1.0, 5)
)

train_mean = train_scores.mean(axis=1)
val_mean = val_scores.mean(axis=1)

# %%
plt.plot(train_sizes, train_mean, label="Training Score")
plt.plot(train_sizes, val_mean, label="Validation Score")

plt.xlabel("Training Size")
plt.ylabel("R2 Score")
plt.title("Learning Curve")
plt.savefig("Learning_curve.png")
plt.legend()
plt.show()

# %%
print("Training Scores:", train_mean)
print("Validation Scores:", val_mean)
# Out:
# Training Scores: [ 0.00000000e+00  0.00000000e+00 -1.43607745e-27 -1.41025641e+01
#  -6.43101384e+01]
# Validation Scores: [-118341.66666667  -13407.63888889   -7968.75         -2590.054857
#     -481.25143012]
