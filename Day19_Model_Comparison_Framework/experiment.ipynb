# %%
import pandas as pd 
from sklearn.model_selection import cross_val_score,train_test_split,KFold
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
df=pd.read_csv("dataset.csv")
X=df[["area","rooms"]]
y=df["price"]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
model_list={
    "Linear_Regression":LinearRegression(),
    "KNN":KNeighborsRegressor(n_neighbors=3),
    "Decision Tree":DecisionTreeRegressor(random_state=42)

}
kf=KFold(n_splits=3,shuffle=True,random_state=42)
for name,model in model_list.items():
    scores=cross_val_score(model,X_train,y_train,cv=kf,scoring="r2")
    print(f"{name}:")
    print(f"Scores {scores}")
    print(f"Mean Score{scores.mean()}")
    print("-"*30)
# Out:
# Linear_Regression:
# Scores [0.98895061 0.92547137 0.8666687 ]
# Mean Score0.9270302278891999
# ------------------------------
# KNN:
# Scores [-6.35710337e-03 -6.96774194e+00 -1.77777778e+00]
# Mean Score-2.917292272211226
# ------------------------------
# Decision Tree:
# Scores [  0.54975124  -3.91935484 -16.        ]
# Mean Score-6.456534531642862
# ------------------------------
